# %% [markdown]
# ### Investigation
#
# Looking for nice statistical patterns or distributions of data, using raw data from the CSO.
#
# This is just a rough investigation, as I have not finalized my intentions for this project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/cso.csv')
df
# Out:
#                                            .1 1997Q4  1998Q1  1998Q2  1998Q3  \
# 0   Both sexes                            NaN    NaN     NaN     NaN     NaN
# 1                                     At work     ..  1418.4  1438.0  1474.1
# 2                                  Unemployed     ..   158.8   152.9   149.7
# 3                                     Student     ..   357.9   358.6   334.7
# 4                      Engaged on home duties     ..   588.4   587.0   591.2
# 5                     Retired from employment     ..   254.7   253.2   254.4
# 6                                       Other     ..    79.1    82.7    84.2
# 7               All principal economic status     ..  2857.2  2872.4  2888.5
# 8         Male                            NaN    NaN     NaN     NaN     NaN
# 9                                     At work     ..   873.0   883.9   903.2
# 10                                 Unemployed     ..   115.2   109.3   107.3
# ...

# %%
df = df.drop([0])
df = df.drop(df.columns[[0, 1]], axis = 1)
y = df.loc[0:7]
y
# Out:
#    1998Q1  1998Q2  1998Q3  1998Q4  1999Q1  1999Q2  1999Q3  1999Q4  2000Q1  \
# 1  1418.4  1438.0  1474.1  1484.2  1505.2  1523.0  1563.1  1577.7  1581.0
# 2   158.8   152.9   149.7   136.9   130.7   125.0   122.5   113.6   115.3
# 3   357.9   358.6   334.7   350.3   355.9   353.5   330.7   349.2   360.8
# 4   588.4   587.0   591.2   591.7   582.2   576.7   581.0   574.9   567.3
# 5   254.7   253.2   254.4   250.3   248.2   248.4   245.7   247.8   248.3
# 6    79.1    82.7    84.2    87.2    84.1    88.4    87.5    84.2    81.4
# 7  2857.2  2872.4  2888.5  2900.4  2906.3  2915.0  2930.5  2947.4  2954.2
#
#    2000Q2   ...    2015Q1  2015Q2  2015Q3  2015Q4  2016Q1  2016Q2  2016Q3  \
# 1  1599.0   ...    1876.8  1902.8  1922.8  1930.5  1926.1  1941.1  1961.7
# 2   108.4   ...     263.1   245.0   246.9   229.6   222.7   221.8   220.6
# 3   359.6   ...     419.3   409.9   388.8   408.7   419.6   408.8   392.9
# 4   564.2   ...     475.5   476.7   477.1   458.4   455.0   454.6   445.2
# ...

# %%
atwork = y.iloc[0]
unemploy = y.iloc[1]
student = y.iloc[2]
home = y.iloc[3]
retired = y.iloc[4]

# %%
x = np.arange(1998, 2017.5, 0.25)
plt.plot(x, atwork, 'k.', label = 'At Work')
plt.plot(x, home, 'm.', label = 'Home Duties')
plt.plot(x, student, 'b.', label = 'Student')
plt.plot(x, retired, 'g.', label = 'Retired')
plt.plot(x, unemploy, 'r.', label = 'Unemployed')
plt.xlim(1997, 2018, 1)
plt.xticks(np.arange(1998, 2017.5, 3))
plt.title('Irish Population by Activity')
plt.legend()
plt.show()
